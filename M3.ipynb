# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from os import listdir
import glob
from PIL import Image
import cv2
from random import randrange
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
ori_images = 'datasets/Images'
mask_images = 'datasets/Masks'

# %%
def load_data(split=0.2):
    images = [f for f in glob.glob(ori_images + "/*.jpg", recursive=True)]
    masks = [f for f in glob.glob(mask_images + "/*.jpg", recursive=True)]

    train_x, test_x = train_test_split(images, test_size=split, random_state=42)
    train_y, test_y = train_test_split(masks, test_size=split, random_state=42)

    return (train_x, train_y), (test_x, test_y)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR) 
    x = cv2.resize(x, (256, 256))
    x = x/255.0
    x = x.astype(np.float32)
    return x

# %%
def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  
    x = cv2.resize(x, (256, 256))
    x = x/255.0
    x = x.astype(np.float32)                   
    x = np.expand_dims(x, axis=-1)              
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([256, 256, 3])
    y.set_shape([256, 256, 1])
    return x, y

def tf_dataset(X, Y, batch):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
(train_x, train_y), (test_x, test_y) = load_data()

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Test: {len(test_x)} - {len(test_y)}")
# Out:
# Train: 336 - 336
# Test: 84 - 84

# %%
batch = 4
train_dataset = tf_dataset(train_x, train_y, batch)
valid_dataset = tf_dataset(test_x, test_y, batch)

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    """ Encoder """
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    """ Bridge """
    b1 = conv_block(p4, 1024)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    """ Outputs """
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    """ Model """
    model = Model(inputs, outputs)
    return model

# %%
model = build_unet((256, 256, 3))
model.compile(loss="binary_crossentropy", optimizer=Adam(), metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  524544     ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
model_path = 'files/final_model.h5'
callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True)
    ]

# %%
batch_size = 32
num_epoch = 50

# %%
model.fit(
    train_dataset.repeat(),
    epochs=num_epoch,
    validation_data=valid_dataset.repeat(),
    steps_per_epoch=len(train_x)//batch_size,
    validation_steps=len(test_x)//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5634 - accuracy: 0.4600
# Epoch 1: val_loss improved from inf to 280.26202, saving model to files\final_model.h5
# 10/10 [==============================] - 62s 6s/step - loss: 0.5634 - accuracy: 0.4600 - val_loss: 280.2620 - val_accuracy: 0.0198
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 0.3305 - accuracy: 0.5955
# Epoch 2: val_loss did not improve from 280.26202
# 10/10 [==============================] - 60s 6s/step - loss: 0.3305 - accuracy: 0.5955 - val_loss: 367.6288 - val_accuracy: 0.0233
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.5743
# Epoch 3: val_loss did not improve from 280.26202
# 10/10 [==============================] - 59s 6s/step - loss: 0.3152 - accuracy: 0.5743 - val_loss: 1300.8070 - val_accuracy: 0.0240
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2770 - accuracy: 0.5960
# Epoch 4: val_loss improved from 280.26202 to 1.83437, saving model to files\final_model.h5
# 10/10 [==============================] - 59s 6s/step - loss: 0.2770 - accuracy: 0.5960 - val_loss: 1.8344 - val_accuracy: 0.0640
# Epoch 5/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2465 - accuracy: 0.6024
# Epoch 5: val_loss improved from 1.83437 to 1.62468, saving model to files\final_model.h5
# 10/10 [==============================] - 60s 6s/step - loss: 0.2465 - accuracy: 0.6024 - val_loss: 1.6247 - val_accuracy: 0.4396
# Epoch 6/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2228 - accuracy: 0.6295
# Epoch 6: val_loss improved from 1.62468 to 0.79269, saving model to files\final_model.h5
# 10/10 [==============================] - 60s 6s/step - loss: 0.2228 - accuracy: 0.6295 - val_loss: 0.7927 - val_accuracy: 0.1689
# Epoch 7/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2169 - accuracy: 0.6266
# Epoch 7: val_loss improved from 0.79269 to 0.36416, saving model to files\final_model.h5
# 10/10 [==============================] - 59s 6s/step - loss: 0.2169 - accuracy: 0.6266 - val_loss: 0.3642 - val_accuracy: 0.5861
# Epoch 8/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2144 - accuracy: 0.6155
# Epoch 8: val_loss improved from 0.36416 to 0.35107, saving model to files\final_model.h5
# 10/10 [==============================] - 58s 6s/step - loss: 0.2144 - accuracy: 0.6155 - val_loss: 0.3511 - val_accuracy: 0.5859
# Epoch 9/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2229 - accuracy: 0.5829
# Epoch 9: val_loss did not improve from 0.35107
# 10/10 [==============================] - 58s 6s/step - loss: 0.2229 - accuracy: 0.5829 - val_loss: 0.3617 - val_accuracy: 0.5848
# Epoch 10/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2059 - accuracy: 0.5953
# Epoch 10: val_loss improved from 0.35107 to 0.33463, saving model to files\final_model.h5
# 10/10 [==============================] - 58s 6s/step - loss: 0.2059 - accuracy: 0.5953 - val_loss: 0.3346 - val_accuracy: 0.5859
# Epoch 11/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2056 - accuracy: 0.5891
# Epoch 11: val_loss improved from 0.33463 to 0.32974, saving model to files\final_model.h5
# 10/10 [==============================] - 58s 6s/step - loss: 0.2056 - accuracy: 0.5891 - val_loss: 0.3297 - val_accuracy: 0.5859
# Epoch 12/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2020 - accuracy: 0.5949
# Epoch 12: val_loss did not improve from 0.32974
# 10/10 [==============================] - 57s 6s/step - loss: 0.2020 - accuracy: 0.5949 - val_loss: 0.3482 - val_accuracy: 0.5857
# Epoch 13/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1961 - accuracy: 0.6009
# Epoch 13: val_loss did not improve from 0.32974
# 10/10 [==============================] - 59s 6s/step - loss: 0.1961 - accuracy: 0.6009 - val_loss: 0.3618 - val_accuracy: 0.5857
# Epoch 14/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.6142
# Epoch 14: val_loss did not improve from 0.32974
# 10/10 [==============================] - 61s 6s/step - loss: 0.1837 - accuracy: 0.6142 - val_loss: 0.3554 - val_accuracy: 0.5816
# Epoch 15/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1714 - accuracy: 0.6347
# Epoch 15: val_loss did not improve from 0.32974
# 10/10 [==============================] - 60s 6s/step - loss: 0.1714 - accuracy: 0.6347 - val_loss: 0.3532 - val_accuracy: 0.5717
# Epoch 16/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.6307
# Epoch 16: val_loss did not improve from 0.32974
# 10/10 [==============================] - 62s 6s/step - loss: 0.1778 - accuracy: 0.6307 - val_loss: 0.3479 - val_accuracy: 0.5806
# Epoch 17/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1927 - accuracy: 0.5970
# Epoch 17: val_loss did not improve from 0.32974
# 10/10 [==============================] - 60s 6s/step - loss: 0.1927 - accuracy: 0.5970 - val_loss: 3.1060 - val_accuracy: 0.1908
# Epoch 18/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1919 - accuracy: 0.5824
# Epoch 18: val_loss did not improve from 0.32974
# 10/10 [==============================] - 61s 6s/step - loss: 0.1919 - accuracy: 0.5824 - val_loss: 2.3957 - val_accuracy: 0.5861
# Epoch 19/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1737 - accuracy: 0.6115
# Epoch 19: val_loss did not improve from 0.32974
# 10/10 [==============================] - 59s 6s/step - loss: 0.1737 - accuracy: 0.6115 - val_loss: 0.7911 - val_accuracy: 0.5852
# Epoch 20/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1914 - accuracy: 0.5787
# Epoch 20: val_loss did not improve from 0.32974
# 10/10 [==============================] - 58s 6s/step - loss: 0.1914 - accuracy: 0.5787 - val_loss: 0.6922 - val_accuracy: 0.5846
# Epoch 21/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1757 - accuracy: 0.6068
# Epoch 21: val_loss did not improve from 0.32974
# 10/10 [==============================] - 58s 6s/step - loss: 0.1757 - accuracy: 0.6068 - val_loss: 0.4578 - val_accuracy: 0.5844
# Epoch 22/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1766 - accuracy: 0.6043
# Epoch 22: val_loss did not improve from 0.32974
# 10/10 [==============================] - 60s 6s/step - loss: 0.1766 - accuracy: 0.6043 - val_loss: 0.3817 - val_accuracy: 0.5722
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1656 - accuracy: 0.6308
# Epoch 23: val_loss improved from 0.32974 to 0.29725, saving model to files\final_model.h5
# 10/10 [==============================] - 61s 6s/step - loss: 0.1656 - accuracy: 0.6308 - val_loss: 0.2972 - val_accuracy: 0.5715
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 0.6328
# Epoch 24: val_loss did not improve from 0.29725
# 10/10 [==============================] - 58s 6s/step - loss: 0.1639 - accuracy: 0.6328 - val_loss: 0.3036 - val_accuracy: 0.5701
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.6209
# Epoch 25: val_loss did not improve from 0.29725
# 10/10 [==============================] - 57s 6s/step - loss: 0.1674 - accuracy: 0.6209 - val_loss: 0.3409 - val_accuracy: 0.5664
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 0.5850
# Epoch 26: val_loss did not improve from 0.29725
# 10/10 [==============================] - 58s 6s/step - loss: 0.1819 - accuracy: 0.5850 - val_loss: 0.3111 - val_accuracy: 0.5694
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.5963
# Epoch 27: val_loss did not improve from 0.29725
# 10/10 [==============================] - 57s 6s/step - loss: 0.1674 - accuracy: 0.5963 - val_loss: 0.3265 - val_accuracy: 0.5712
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1792 - accuracy: 0.5838
# Epoch 28: val_loss did not improve from 0.29725
# 10/10 [==============================] - 58s 6s/step - loss: 0.1792 - accuracy: 0.5838 - val_loss: 0.3345 - val_accuracy: 0.5652
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1649 - accuracy: 0.6047
# Epoch 29: val_loss did not improve from 0.29725
# 10/10 [==============================] - 58s 6s/step - loss: 0.1649 - accuracy: 0.6047 - val_loss: 0.3585 - val_accuracy: 0.5720
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1683 - accuracy: 0.6005
# Epoch 30: val_loss did not improve from 0.29725
# 10/10 [==============================] - 57s 6s/step - loss: 0.1683 - accuracy: 0.6005 - val_loss: 0.3508 - val_accuracy: 0.5671
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1546 - accuracy: 0.6293
# Epoch 31: val_loss did not improve from 0.29725
# 10/10 [==============================] - 57s 6s/step - loss: 0.1546 - accuracy: 0.6293 - val_loss: 0.3238 - val_accuracy: 0.5667
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.6404
# Epoch 32: val_loss did not improve from 0.29725
# 10/10 [==============================] - 57s 6s/step - loss: 0.1484 - accuracy: 0.6404 - val_loss: 0.3008 - val_accuracy: 0.5669
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1648 - accuracy: 0.6134
# Epoch 33: val_loss did not improve from 0.29725
# 10/10 [==============================] - 59s 6s/step - loss: 0.1648 - accuracy: 0.6134 - val_loss: 0.3163 - val_accuracy: 0.5684
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1683 - accuracy: 0.6015
# Epoch 34: val_loss did not improve from 0.29725
# 10/10 [==============================] - 61s 6s/step - loss: 0.1683 - accuracy: 0.6015 - val_loss: 0.3270 - val_accuracy: 0.5697
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.5937
# Epoch 35: val_loss did not improve from 0.29725
# 10/10 [==============================] - 58s 6s/step - loss: 0.1626 - accuracy: 0.5937 - val_loss: 0.2989 - val_accuracy: 0.5710
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1631 - accuracy: 0.5927
# Epoch 36: val_loss did not improve from 0.29725
# 10/10 [==============================] - 60s 6s/step - loss: 0.1631 - accuracy: 0.5927 - val_loss: 0.3239 - val_accuracy: 0.5615
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1602 - accuracy: 0.6025
# Epoch 37: val_loss did not improve from 0.29725
# 10/10 [==============================] - 60s 6s/step - loss: 0.1602 - accuracy: 0.6025 - val_loss: 0.3295 - val_accuracy: 0.5692
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1681 - accuracy: 0.5847
# Epoch 38: val_loss did not improve from 0.29725
# 10/10 [==============================] - 60s 6s/step - loss: 0.1681 - accuracy: 0.5847 - val_loss: 0.3235 - val_accuracy: 0.5685
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.6175
# Epoch 39: val_loss did not improve from 0.29725
# 10/10 [==============================] - 57s 6s/step - loss: 0.1543 - accuracy: 0.6175 - val_loss: 0.3044 - val_accuracy: 0.5688
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1461 - accuracy: 0.6400
# Epoch 40: val_loss improved from 0.29725 to 0.28633, saving model to files\final_model.h5
# 10/10 [==============================] - 58s 6s/step - loss: 0.1461 - accuracy: 0.6400 - val_loss: 0.2863 - val_accuracy: 0.5726
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1469 - accuracy: 0.6316
# Epoch 41: val_loss improved from 0.28633 to 0.28604, saving model to files\final_model.h5
# 10/10 [==============================] - 58s 6s/step - loss: 0.1469 - accuracy: 0.6316 - val_loss: 0.2860 - val_accuracy: 0.5703
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1584 - accuracy: 0.6146
# Epoch 42: val_loss improved from 0.28604 to 0.26811, saving model to files\final_model.h5
# 10/10 [==============================] - 58s 6s/step - loss: 0.1584 - accuracy: 0.6146 - val_loss: 0.2681 - val_accuracy: 0.5746
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1699 - accuracy: 0.5791
# Epoch 43: val_loss did not improve from 0.26811
# 10/10 [==============================] - 60s 6s/step - loss: 0.1699 - accuracy: 0.5791 - val_loss: 0.2993 - val_accuracy: 0.5708
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1516 - accuracy: 0.6077
# Epoch 44: val_loss improved from 0.26811 to 0.25462, saving model to files\final_model.h5
# 10/10 [==============================] - 62s 6s/step - loss: 0.1516 - accuracy: 0.6077 - val_loss: 0.2546 - val_accuracy: 0.5745
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.5843
# Epoch 45: val_loss did not improve from 0.25462
# 10/10 [==============================] - 59s 6s/step - loss: 0.1693 - accuracy: 0.5843 - val_loss: 0.2869 - val_accuracy: 0.5725
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1536 - accuracy: 0.6060
# Epoch 46: val_loss improved from 0.25462 to 0.25183, saving model to files\final_model.h5
# 10/10 [==============================] - 62s 6s/step - loss: 0.1536 - accuracy: 0.6060 - val_loss: 0.2518 - val_accuracy: 0.5773
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1519 - accuracy: 0.6088
# Epoch 47: val_loss did not improve from 0.25183
# 10/10 [==============================] - 63s 6s/step - loss: 0.1519 - accuracy: 0.6088 - val_loss: 0.2849 - val_accuracy: 0.5730
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.6360
# Epoch 48: val_loss did not improve from 0.25183
# 10/10 [==============================] - 63s 6s/step - loss: 0.1453 - accuracy: 0.6360 - val_loss: 0.2594 - val_accuracy: 0.5808
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.6319
# Epoch 49: val_loss did not improve from 0.25183
# 10/10 [==============================] - 60s 6s/step - loss: 0.1425 - accuracy: 0.6319 - val_loss: 0.2679 - val_accuracy: 0.5815
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1506 - accuracy: 0.6204
# Epoch 50: val_loss improved from 0.25183 to 0.21441, saving model to files\final_model.h5
# 10/10 [==============================] - 63s 6s/step - loss: 0.1506 - accuracy: 0.6204 - val_loss: 0.2144 - val_accuracy: 0.5834

# %%
def graph():
    #Plot training & validation accuracy values
    plt.plot(model.history.history['accuracy'])
    plt.plot(model.history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(model.history.history['loss'])
    plt.plot(model.history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

graph()
